# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.34.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.11.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-0.34.0-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.0/136.0 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.34.0

# %%
import os
os.environ["GROQ_API_KEY"] = "Sua_Key"

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API"),  # This is the default and can be omitted
)

# %% [markdown]
# - Use Prompts específicos
# - Instruções Precisas e Detalhadas
# - Controle o formato da resposta
# - Use separadores para organizar informações

# %%
print("## Exemplo 5: Combinação de Princípios\n")

system_prompt = """
Você é um estrategista de marketing criativo.
Sempre siga o formato solicitado e use linguagem clara e objetiva.
"""

user_prompt = """
TAREFA: Criar um mini plano de marketing para lançamento de um aplicativo fitness.

--- INFORMAÇÕES ---
Público: jovens de 18-30 anos
Orçamento: R$ 50.000
Objetivo: 10.000 downloads no primeiro mês
--- FIM ---

FORMATO DA RESPOSTA:
1. POSICIONAMENTO (2 frases)
2. CANAIS DE MARKETING (3 itens numerados)
3. AÇÃO CRIATIVA PRINCIPAL (1 frase)
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.6,
    max_completion_tokens=800
)

print("Resposta final:")
print(response.choices[0].message.content)
# Out:
# ## Exemplo 5: Combinação de Princípios
#
# Resposta final:
# 1. **POSICIONAMENTO**
# O app se posiciona como o parceiro digital que transforma a rotina fitness dos jovens, oferecendo treinos curtos, gamificados e comunidade motivadora.
# É a solução prática e social para quem quer resultados reais sem perder tempo.
#
# 2. **CANAIS DE MARKETING**
# 1. TikTok & Reels: micro‑vídeos de desafios de 15 s com influenciadores fitness, impulsionados por anúncios pagos.
# 2. Parcerias com universidades e academias: eventos pop‑up de treinos ao vivo e QR Code para download gratuito.
# 3. Marketing de performance no Google/Apple Store: campanhas de CPA focadas em palavras‑chave como “treino rápido” e “fitness app”.
#
# 3. **AÇÃO CRIATIVA PRINCIPAL**
# Lançar o “Desafio 30‑Day Fit”, um concurso de 30 dias onde os usuários compartilham seu progresso nas redes usando a hashtag #30DayFit e concorrem a prêmios de equipamentos e assinaturas premium.
